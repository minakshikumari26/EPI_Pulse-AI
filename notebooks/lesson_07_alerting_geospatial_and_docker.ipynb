# %% [markdown]
# # Lesson 7: Alerting, Geospatial Output, and Docker
#
# This lesson covers alert generation, heatmap output, and Docker Compose.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

from src.alerting.alert_generator import generate_alert

generate_alert(cases=45, risk_score=62)

# %%
from src.geospatial.heatmap import create_heatmap

create_heatmap()
'Open models/outbreak_heatmap.html in a browser to view the heatmap.'

# %% [markdown]
# ## Docker
#
# Run this from the project root:
#
# ```powershell
# docker compose up --build
# ```
#
# Expected services:
#
# - API on port `8000`
# - dashboard on port `8501`
# - Postgres on port `5432`
