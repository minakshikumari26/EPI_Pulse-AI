# %% [markdown]
# # Lesson 2: Data and Preprocessing
#
# The main dataset is `data/disease_data.csv`. It contains daily synthetic outbreak data for multiple Indian regions.

# %%
import pandas as pd

df = pd.read_csv('../data/disease_data.csv')
df.head()

# %%
df.groupby('region').size()

# %% [markdown]
# ## Cleaning Script
#
# The cleaning script removes duplicates, fills missing numeric values, converts `date` to datetime, and returns a cleaned dataframe.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

from src.preprocessing.clean_data import load_and_clean_data

clean_df = load_and_clean_data()
clean_df.head()
