# %% [markdown]
# # Lesson 3: Feature Engineering and Risk Scoring
#
# This lesson creates region-wise features and calculates risk levels.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.preprocessing.feature_engineering import create_features

features_df = create_features()
features_df[['date', 'region', 'cases', 'rolling_avg_cases', 'previous_day_cases', 'growth_rate']].head(10)

# %% [markdown]
# The important point: rolling averages, previous-day cases, and growth rate are calculated within each region.

# %%
from src.risk_scoring.risk_score import calculate_risk

risk_df = calculate_risk()
risk_df[['date', 'region', 'cases', 'risk_score', 'risk_level']].head()
