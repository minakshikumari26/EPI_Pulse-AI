# %% [markdown]
# # Lesson 4: Anomaly Detection
#
# This lesson covers z-score spike detection and Isolation Forest anomaly detection.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.anomaly_detection.detect_spikes import detect_spikes

spikes = detect_spikes()
spikes.head()

# %%
from src.anomaly_detection.isolation_forest_detector import detect_anomalies

anomalies = detect_anomalies()
anomalies.head()

# %% [markdown]
# Z-score is easy to explain for case spikes. Isolation Forest is broader because it can detect unusual combinations of cases and weather.
