# %% [markdown]
# # Lesson 5: Forecasting
#
# This lesson runs region-wise ARIMA and Prophet forecasts.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.forecasting.arima_model import arima_forecast

arima_results = arima_forecast()
arima_results.head()

# %%
from src.forecasting.prophet_model import forecast_cases

prophet_results = forecast_cases()
prophet_results.head()

# %% [markdown]
# ARIMA is useful as a statistical baseline. Prophet is useful for trend-focused forecasting.
